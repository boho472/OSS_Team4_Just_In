# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HybridTrack-modify2
# Out:
# /content/drive/MyDrive/HybridTrack-modify2

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=382c919af4d9e095c6ae213213a435c3ad5775fc448c1ad9d59a3582e7927228
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=6f5aa0e01ce0b25c3771601a5e8ca1f3f395a5faa125c832afaf0fc77cecf8dd
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python src/run_tracking.py
# Out:
# [Frame 0] INIT   → active_after=[0, 1, 2, 3]
# [{'object_id': 0, 'bbox': {'x': 1003.0, 'y': 575.0, 'w': 1150.0, 'h': 943.0}, 'gap_btw_18_nseen': 0}, {'object_id': 1, 'bbox': {'x': 1355.0, 'y': 657.0, 'w': 1507.0, 'h': 935.0}, 'gap_btw_18_nseen': 0}, {'object_id': 2, 'bbox': {'x': 424.0, 'y': 545.0, 'w': 729.0, 'h': 963.0}, 'gap_btw_18_nseen': 0}, {'object_id': 3, 'bbox': {'x': 912.0, 'y': 549.0, 'w': 939.0, 'h': 630.0}, 'gap_btw_18_nseen': 0}]
#
# [Frame 1] ASSOC  → ids=[0, 1, 2, 3]   (active_before=[0, 1, 2, 3])
# [Frame 1] INIT   → active_after=[0, 1, 2, 3]
# [{'object_id': 0, 'bbox': {'x': 1003.0, 'y': 577.0, 'w': 1150.0, 'h': 943.0}, 'gap_btw_18_nseen': 0}, {'object_id': 1, 'bbox': {'x': 1354.0, 'y': 659.0, 'w': 1506.0, 'h': 931.0}, 'gap_btw_18_nseen': 0}, {'object_id': 2, 'bbox': {'x': 422.0, 'y': 549.0, 'w': 728.0, 'h': 964.0}, 'gap_btw_18_nseen': 0}, {'object_id': 3, 'bbox': {'x': 911.0, 'y': 549.0, 'w': 939.0, 'h': 631.0}, 'gap_btw_18_nseen': 0}]
#
# ...

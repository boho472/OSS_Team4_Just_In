# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HybridTrack-main
# Out:
# /content/drive/MyDrive/HybridTrack-main

# %%
# !pip install fvcore
# Out:
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fvcore) (2.0.2)
# Collecting yacs>=0.1.6 (from fvcore)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from fvcore) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fvcore) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore) (3.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from fvcore) (11.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.7->fvcore) (4.15.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=4ae76c140734da3e8ee32da9628571181f46adedde2313764fb5e7b2a0b7c132
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=9678b2279bdec5624b1dc42a3640740bca9a68e47b577d73a8188093388e92e0
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-3.2.0 yacs-0.1.8

# %%
# !python src/run_tracking.py
# Out:
# config file: src/configs/tracking.yaml
# data path:  src/data/KITTI/tracking/training
# detections path:  src/data/KITTI/tracking/detections/virconv/training
# tracking class: Pedestrian
# tracking seqs:  [21]
#   0% 0/1 [00:00<?, ?it/s]TRACKING SEQIN 21
# [Frame 0] INIT   → active_after=[0, 1, 2, 3, 4, 5]
# [Frame 3] ASSOC  → ids=[0, 1, 2, 3, 4, 5]   (active_before=[0, 1, 2, 3, 4, 5])
# [Frame 3] INIT   → active_after=[0, 1, 2, 3, 4, 5]
# [Frame 6] ASSOC  → ids=[0, 2, 1, 3, 4, 5]   (active_before=[0, 1, 2, 3, 4, 5])
# [Frame 6] INIT   → active_after=[0, 1, 2, 3, 4, 5]
# [Frame 9] ASSOC  → ids=[0, 3, 1, 2, 4, 5]   (active_before=[0, 1, 2, 3, 4, 5])
# [Frame 9] INIT   → active_after=[0, 1, 2, 3, 4, 5]
# [Frame 12] ASSOC  → ids=[0, 3, 1, 2, 4, 5]   (active_before=[0, 1, 2, 3, 4, 5])
# [Frame 12] INIT   → active_after=[0, 1, 2, 3, 4, 5]
# [Frame 15] ASSOC  → ids=[0, 3, 4, 2, 1, 5, 6, 7]   (active_before=[0, 1, 2, 3, 4, 5])
# [Frame 15] INIT   → active_after=[0, 1, 2, 3, 4, 5, 6, 7]
# [Frame 18] ASSOC  → ids=[0, 3, 2, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 6, 7])
# [Frame 18] INIT   → active_after=[0, 1, 2, 3, 4, 5, 6, 7]
# [Frame 21] ASSOC  → ids=[0, 3, 2, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 6, 7])
# [Frame 21] INIT   → active_after=[0, 1, 2, 3, 4, 5, 6, 7]
# [Frame 24] ASSOC  → ids=[0, 2, 3, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 24] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 27] ASSOC  → ids=[0, 3, 2, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 27] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 30] ASSOC  → ids=[0, 3, 1, 2, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 30] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 33] ASSOC  → ids=[0, 3, 1, 2, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 33] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 36] ASSOC  → ids=[0, 2, 3, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 36] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 39] ASSOC  → ids=[0, 2, 3, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 39] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 42] ASSOC  → ids=[0, 2, 3, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 42] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 45] ASSOC  → ids=[0, 3, 2, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 45] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7]
# [Frame 48] ASSOC  → ids=[0, 2, 8, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7])
# [Frame 48] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8]
# [Frame 51] ASSOC  → ids=[0, 2, 8, 1, 4, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7, 8])
# [Frame 51] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8]
# [Frame 54] ASSOC  → ids=[0, 8, 4, 2, 1, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7, 8])
# [Frame 54] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8]
# [Frame 57] ASSOC  → ids=[0, 2, 8, 4, 1, 5, 9]   (active_before=[0, 1, 2, 3, 4, 5, 7, 8])
# [Frame 57] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8, 9]
# [Frame 60] ASSOC  → ids=[0, 2, 10, 4, 1, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7, 8, 9])
# [Frame 60] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8, 9, 10]
# [Frame 63] ASSOC  → ids=[0, 10, 2, 4, 1, 5, 7]   (active_before=[0, 1, 2, 3, 4, 5, 7, 8, 9, 10])
# [Frame 63] INIT   → active_after=[0, 1, 2, 3, 4, 5, 7, 8, 9, 10]
# [Frame 66] ASSOC  → ids=[0, 11, 4, 2, 1, 5, 12, 7]   (active_before=[0, 1, 2, 4, 5, 7, 8, 10])
# [Frame 66] INIT   → active_after=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12]
# [Frame 69] ASSOC  → ids=[11, 0, 4, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12])
# [Frame 69] INIT   → active_after=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12]
# [Frame 72] ASSOC  → ids=[11, 0, 4, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12])
# [Frame 72] INIT   → active_after=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12]
# [Frame 75] ASSOC  → ids=[11, 0, 4, 2, 1, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12])
# [Frame 75] INIT   → active_after=[0, 1, 2, 4, 5, 7, 8, 10, 11, 12]
# [Frame 78] ASSOC  → ids=[0, 11, 4, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 10, 11, 12])
# [Frame 78] INIT   → active_after=[0, 1, 2, 4, 5, 7, 10, 11, 12]
# [Frame 81] ASSOC  → ids=[0, 11, 4, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 10, 11, 12])
# [Frame 81] INIT   → active_after=[0, 1, 2, 4, 5, 7, 10, 11, 12]
# [Frame 84] ASSOC  → ids=[0, 11, 1, 2, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 84] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 87] ASSOC  → ids=[0, 11, 4, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 87] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 90] ASSOC  → ids=[0, 2, 11, 1, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 90] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 93] ASSOC  → ids=[0, 2, 11, 1, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 93] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 96] ASSOC  → ids=[0, 2, 11, 1, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 96] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 99] ASSOC  → ids=[0, 1, 2, 4, 11, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 99] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 102] ASSOC  → ids=[0, 1, 2, 4, 11, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 102] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 105] ASSOC  → ids=[0, 4, 2, 11, 1, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 105] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 108] ASSOC  → ids=[2, 0, 11, 1, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 108] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 111] ASSOC  → ids=[2, 0, 11, 1, 4, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 111] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 114] ASSOC  → ids=[2, 0, 4, 11, 1, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 114] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 117] ASSOC  → ids=[0, 2, 4, 1, 11, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 117] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 120] ASSOC  → ids=[0, 4, 11, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 120] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 123] ASSOC  → ids=[0, 4, 11, 1, 2, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 123] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 126] ASSOC  → ids=[0, 11, 2, 4, 1, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 126] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12]
# [Frame 129] ASSOC  → ids=[0, 4, 11, 1, 13, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12])
# [Frame 129] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13]
# [Frame 132] ASSOC  → ids=[0, 4, 11, 1, 13, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13])
# [Frame 132] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13]
# [Frame 135] ASSOC  → ids=[4, 0, 11, 13, 1, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13])
# [Frame 135] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13]
# [Frame 138] ASSOC  → ids=[0, 4, 13, 1, 11, 12, 5, 7, 14]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13])
# [Frame 138] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14]
# [Frame 141] ASSOC  → ids=[0, 4, 13, 1, 11, 12, 5, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14])
# [Frame 141] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14]
# [Frame 144] ASSOC  → ids=[4, 0, 2, 11, 1, 12, 5, 14, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14])
# [Frame 144] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14]
# [Frame 147] ASSOC  → ids=[1, 0, 11, 2, 4, 12, 5, 14, 7]   (active_before=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14])
# [Frame 147] INIT   → active_after=[0, 1, 2, 4, 5, 7, 11, 12, 13, 14]
# Memory used for sequence 21: 26443264 bytes
# Processing Framerate for sequence 21: 65.25410255253934 FPS
# Detected Objects per frame for sequence 21: 2.5472972972972974 Objets per Frame
# Total detected Objects for sequence 21: 377 FPS
# Memory used: 9998336 bytes
# 100% 1/1 [00:03<00:00,  3.12s/it]
# Tracking time:  2.268051862716675
# Tracking frames:  148
# Tracking FPS: 65.25423974332115
# Tracking ms: 0.01532467474808564

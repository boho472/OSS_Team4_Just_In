# %%
import os
os.environ['SAM2_BUILD_CUDA'] = '0'
os.environ['SAM2_BUILD_ALLOW_ERRORS'] = '1'
# !pip install -e . -q

# !pip install vot-toolkit
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.4/340.4 kB 15.4 MB/s eta 0:00:00
# ...
#   Created wheel for attributee: filename=attributee-0.1.9-py3-none-any.whl size=13102 sha256=d30bb7ec81c51dcc63f92952d4744a7c4f17cf8a0b2c3ef7615d348207b1d5c4
# ...

# %%
# %cd /content/drive/MyDrive/Multi_Tracking_Person/src/checkpoints
# Out:
# /content/drive/MyDrive/Multi_Tracking_Person/src/checkpoints

# %%
# !chmod +x download_ckpts.sh
# !./download_ckpts.sh
# Out:
# ...
# --2025-12-15 07:35:50--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_tiny.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.171.22.13, 3.171.22.33, 3.171.22.118, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.171.22.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156008466 (149M) [application/vnd.snesdev-page-table]
# Saving to: ‘sam2.1_hiera_tiny.pt.1’
#
# sam2.1_hiera_tiny.p 100%[===================>] 148.78M  80.8MB/s    in 1.8s
#
# 2025-12-15 07:35:52 (80.8 MB/s) - ‘sam2.1_hiera_tiny.pt.1’ saved [156008466/156008466]
#
# ...
# --2025-12-15 07:35:52--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_small.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.171.22.13, 3.171.22.33, 3.171.22.118, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.171.22.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# %cd /content/drive/MyDrive/Multi_Tracking_Person
# Out:
# /content/drive/MyDrive/Multi_Tracking_Person

# %%
# !pip install timm==0.6.7 opencv-python einops

# !pip install fvcore

# !git clone https://github.com/isl-org/ZoeDepth.git

import sys
sys.path.append("/content/ZoeDepth")

# !pip install ultralytics

# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.22
#     Uninstalling timm-1.0.22:
#       Successfully uninstalled timm-1.0.22
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=4f4989f9194acbaf9538a8631f7d4235ebd54670512ab5956c399bbc85aaab59
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# Successfully built fvcore
# ...
# fatal: destination path 'ZoeDepth' already exists and is not an empty directory.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.8 MB/s eta 0:00:00
# ...

# %%
# !python src/run_tracking.py
# Out:
# Streaming output truncated to the last 5000 lines.
#    Processing obj_num=5, obj_id=58
# ...
